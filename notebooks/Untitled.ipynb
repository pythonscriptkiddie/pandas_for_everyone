# %%
from seoanalyzer import analyze

# %%
result = analyze('http://www.fairfaxcitysmiles.com/')

# %%
len(result['pages'])
# Out:
# 3

# %%
result['pages']
# Out:
# [{'url': 'http://www.fairfaxcitysmiles.com',
#   'title': 'home « esthetic dentistry « fairfax « northern virginia',
#   'description': 'esthetic dentistry of fairfax is an affordable dentistry in fairfax va. come see us today and we will brighten up your smile. 703-218-8142.',
#   'word_count': 875,
#   'keywords': [(19, 'dental'),
#    (17, 'dentistry'),
#    (14, 'fairfax'),
#    (13, 'patient'),
#    (8, 'teeth'),
#    (8, 'read'),
#    (7, 'whitening'),
#    (7, 'porcelain'),
#    (7, 'office'),
#    (7, 'cosmetic'),
#    (6, 'specials'),
#    (6, 'smile'),
#    (6, 'restorations'),
#    (6, 'offer'),
#    (6, 'invisalign'),
#    (6, 'family'),
#    (6, 'click'),
#    (6, 'care'),
#    (6, 'bridge'),
#    (6, '2020'),
#    (5, 'va'),
#    (5, 'treatment'),
#    (5, 'health'),
#    (5, 'gum'),
#    (5, 'esthetic'),
#    (5, 'emergency'),
#    (5, 'crowns')],
#   'bigrams': Counter({'home esthetic': 1,
#            'esthetic dentistry': 5,
#            'dentistry fairfax': 1,
# ...
